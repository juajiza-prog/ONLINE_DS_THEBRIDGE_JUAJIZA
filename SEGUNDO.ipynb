# %% [markdown]
# ## Mis primeros pasos con Markdown...
# ...son muy buenos

# %% [markdown]
# # Cabecera 1
# ## Cabecera 2
# ### Cabecera 3
# #### Cabecera 4
# ##### Cabecera 5
# ###### Cabecera 6
# ####### Cabecera 7

# %% [markdown]
# <h1>Header 1</h1>

# %% [markdown]
# **texto en negrita**
# *texto en cursiva*
# ***texto en cursiva y negrita***

# %% [markdown]
# > Recuerda el conocimiento del negocio y dominio
# >> utilizar atajos del teclado

# %% [markdown]
# "En un lugar de la Mancha"
# "veinte años despues"

# %% [markdown]
# "En un lugar de la Mancha"
# "veinte años despues"

# %% [markdown]
# 1. primer elemento
# 2. segundo elemento

# %% [markdown]
# * elemento 1
# * elemento 2
# - elemento 3

# %% [markdown]
# #### Código python

# %% [markdown]
# ```Python
# variable= "esto es euna variable"
# ```

# %% [markdown]
# ### lineas de separacion

# %% [markdown]
# ***
# ---

# %% [markdown]
# Si haces clik en [este enlace](#Mis-primeros-pasos-con-Markdown...), volverás al inicio del notebook.

# %% [markdown]
# ![imagen 1](./imagen1.jpg)

# %% [markdown]
# ![imagen1](./ONLINE_DS_THEBRIDGE_JUAJIZA/IMAGEN1.jpg)

# %% [markdown]
# ![imagen1.jpeg](attachment:89f45ec4-d153-4e08-96d0-b174bd320bcb.jpeg)

# %% [markdown]
# ![imagen2.jpeg](attachment:e9ea691d-c2ac-47f7-81dc-2c5901c5ed98.jpeg)
